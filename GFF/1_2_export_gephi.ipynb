# %%
import networkx as nx 
import numpy as np
import pandas as pd 
import community 
from itertools import compress
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import fcluster
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt 
import seaborn as sns
from seaborn import color_palette, set_style, palplot
plt.style.use('ggplot')
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Export 2009 and 2015 data for gephi

# %% [markdown]
# #### 1. First, define some functions

# %% [markdown]
# ###### Some thing important, for presentation purpuse, we add layer_dummy as edge attribute, so it is not going to be a generalized template

# %%
def preprocess(df):
    keep_var = ['countrycode','counterpart_code','country','counterpart','year','total_claims',
                'total_claims_ratio','country_dummy_link']
    df = df[keep_var]                           ## keep only used variables 
    df = df.replace(np.nan,0)                   ## turn na to zero 
    num = df._get_numeric_data()
    num[num < 0] = 0                            ## turn negative to zero 
    #df['total'] = df['total_claims']

#     df['Banking'] = df['loans_dep']
#     df['Equity'] = df['CDIS_IADE']+ df['CPIS_IAPE']
#     df['Debt'] = df['CDIS_IADD']+ df['CPIS_IAPD']

#     mata = ['countrycode','counterpart_code','country','counterpart','year','layer_dummy']
#     var_org = ['CDIS_IAD','CPIS_IAP','loans_dep','total']
#     var_sum_out = ['CDIS_Sum_out','CPIS_Sum_out','loans_dep_Sum_out','total_Sum_out']
#     var_sum_in = ['CDIS_Sum_in','CPIS_Sum_in','loans_dep_Sum_in','total_Sum_in']
#     var_weight = ['CDIS_weight','CPIS_weight','loans_dep_weight','total_weight']

#     df[var_sum_out]= df.groupby(['countrycode','year'])[var_org].transform(sum)           ## like stata egen sum 
#     df[var_sum_in]= df.groupby(['counterpart_code','year'])[var_org].transform(sum)        ## like stata egen sum 
#     df_weight = pd.DataFrame((df[var_org].values / df[var_sum_out].values)*100,columns=[var_weight])
#     df[var_weight] = df_weight                                                        ## create the weight variables 
#     mata.extend(var_weight)
#     df = df[mata]

    df.fillna(0,inplace=True)
    
    return df 

def export_gephi(df,year,var):
    ## clean the data first 
    df_y = df[df['year']==year]
    df_y.fillna(0,inplace=True)
    df_y = df_y[df_y[var]>0]
    #G = nx.from_pandas_dataframe(df_y, source="country", target="counterpart", edge_attr=var,create_using=nx.DiGraph())
    G = nx.from_pandas_dataframe(df_y, source="counterpart", target="country", edge_attr=[var,'country_dummy_link','total_claims_ratio'],create_using=nx.DiGraph())
    get_pagerank_centrality(G,var)
    nx.set_node_attributes(G, 'country_dummy', 0.0)
    nx.set_node_attributes(G, 'country_dummy', country_dummy_node)
    nx.write_gexf(G, "../result/gexf/"+var+str(year)+".gexf")
    return G
    
def get_pagerank_centrality(G,var):
    p = nx.pagerank(G,weight=var)
    nx.set_node_attributes(G, 'pagerank_centrality', p)

# %% [markdown]
# #### 2. read stata data and export it

# %%
## read pre-processed data from stata
df = pd.read_stata('../data/agg_ratio_with_dummy.dta')
df = preprocess(df)

# %%
df.head()
# Out:
#    countrycode  counterpart_code        country   counterpart  year  \
# 0        111.0             456.0  United States  Saudi Arabia  2009
# 1        111.0             172.0  United States       Finland  2009
# 2        111.0             698.0  United States      Zimbabwe  2009
# 3        111.0             273.0  United States        Mexico  2009
# 4        111.0             233.0  United States      Colombia  2009
#
#     total_claims  total_claims_ratio  country_dummy_link
# 0    8209.000000            0.000629                 2.0
# 1   75817.367188            0.005814                 4.0
# 2      68.000000            0.000005                 4.0
# 3  206413.000000            0.015828                 4.0
# 4   18160.000000            0.001393                 4.0

# %%
country_dummy_node = ["China, P.R.: Mainland", "United States", "United Kingdom", "Swaziland", "Belgium",
                      "France", "Germany", "Italy", "Japan", "Ireland", "Spain",
                      "Luxembourg", "Netherlands", "China, P.R.: Hong Kong"]
country_dummy_node={c:v for c,v in zip(country_dummy_node,[1.0]*len(country_dummy_node))}

# %%
## export all files to gephi
files = [(2009,'total_claims'),(2015,'total_claims')]
for x in files:
    year,var = x 
    G = export_gephi(df,year,var)

# %%
# Out:
# {'Afghanistan, Islamic Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007302278573225256},
#  'Albania': {'country_dummy': 0, 'pagerank_centrality': 0.000819299742480642},
#  'Algeria': {'country_dummy': 0, 'pagerank_centrality': 0.0007747588494695256},
#  'American Samoa': {'country_dummy': 0,
#   'pagerank_centrality': 0.00073268728118854},
#  'Andorra': {'country_dummy': 0, 'pagerank_centrality': 0.0007431059848257687},
#  'Angola': {'country_dummy': 0, 'pagerank_centrality': 0.0009498268326595597},
#  'Anguilla': {'country_dummy': 0,
#   'pagerank_centrality': 0.0010204200806731205},
#  'Antigua and Barbuda': {'country_dummy': 0,
#   'pagerank_centrality': 0.000709123180479836},
#  'Argentina': {'country_dummy': 0,
#   'pagerank_centrality': 0.0012630386839044788},
#  'Armenia, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007188864647653233},
#  'Aruba': {'country_dummy': 0, 'pagerank_centrality': 0.000738112648565891},
#  'Australia': {'country_dummy': 0, 'pagerank_centrality': 0.00916637112337989},
#  'Austria': {'country_dummy': 0, 'pagerank_centrality': 0.008212410981807581},
#  'Azerbaijan, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008176736034929302},
#  'Bahamas, The': {'country_dummy': 0,
#   'pagerank_centrality': 0.003129619102875738},
#  'Bahrain, Kingdom of': {'country_dummy': 0,
#   'pagerank_centrality': 0.004311368977047206},
#  'Bangladesh': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007923693929653958},
#  'Barbados': {'country_dummy': 0,
#   'pagerank_centrality': 0.0012118911660390626},
#  'Belarus': {'country_dummy': 0, 'pagerank_centrality': 0.0007349835201329765},
#  'Belgium': {'country_dummy': 1, 'pagerank_centrality': 0.018591246631458964},
#  'Belize': {'country_dummy': 0, 'pagerank_centrality': 0.0008800444000139932},
#  'Benin': {'country_dummy': 0, 'pagerank_centrality': 0.0007291690280967797},
#  'Bermuda': {'country_dummy': 0, 'pagerank_centrality': 0.01123220104619558},
#  'Bhutan': {'country_dummy': 0, 'pagerank_centrality': 0.0007128099810584339},
#  'Bolivia': {'country_dummy': 0, 'pagerank_centrality': 0.0007593731368855134},
#  'Bosnia and Herzegovina': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007273839441555191},
#  'Botswana': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007639004026544053},
#  'Brazil': {'country_dummy': 0, 'pagerank_centrality': 0.004519679620961149},
#  'British Indian Ocean Territory': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007132735730940733},
#  'Brunei Darussalam': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007743105680923959},
#  'Bulgaria': {'country_dummy': 0,
#   'pagerank_centrality': 0.0009206483352895008},
#  'Burkina Faso': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007287134746640932},
#  'Burundi': {'country_dummy': 0, 'pagerank_centrality': 0.0007093909356205264},
#  'Cabo Verde': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007233632507327679},
#  'Cambodia': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007310275949349364},
#  'Cameroon': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007236756446488635},
#  'Canada': {'country_dummy': 0, 'pagerank_centrality': 0.020072431790642005},
#  'Cayman Islands': {'country_dummy': 0,
#   'pagerank_centrality': 0.014383829325072294},
#  'Central African Republic': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007105341970122146},
#  'Chad': {'country_dummy': 0, 'pagerank_centrality': 0.0007095355779032925},
#  'Chile': {'country_dummy': 0, 'pagerank_centrality': 0.002286222062606546},
#  'China, P.R.: Hong Kong': {'country_dummy': 1,
#   'pagerank_centrality': 0.02449291871233478},
#  'China, P.R.: Macao': {'country_dummy': 0,
#   'pagerank_centrality': 0.0016609396086827084},
#  'China, P.R.: Mainland': {'country_dummy': 1,
#   'pagerank_centrality': 0.011385060258750945},
#  'Colombia': {'country_dummy': 0, 'pagerank_centrality': 0.001392704459963422},
#  'Congo, Democratic Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.000822851209109523},
#  'Congo, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007207977424007854},
#  'Cook Islands': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008069186470386993},
#  'Costa Rica': {'country_dummy': 0,
#   'pagerank_centrality': 0.0009766529780571615},
#  "Cote d'Ivoire": {'country_dummy': 0,
#   'pagerank_centrality': 0.0008033344386999064},
#  'Croatia': {'country_dummy': 0, 'pagerank_centrality': 0.0009993697873918372},
#  'Cuba': {'country_dummy': 0, 'pagerank_centrality': 0.0007268524169037208},
#  'Curacao': {'country_dummy': 0, 'pagerank_centrality': 0.0007075471698113208},
#  'Curacao & St. Maarten': {'country_dummy': 0,
#   'pagerank_centrality': 0.0017044694089571493},
#  'Cyprus': {'country_dummy': 0, 'pagerank_centrality': 0.0025707967523647605},
#  'Czech Republic': {'country_dummy': 0,
#   'pagerank_centrality': 0.0014472796115983007},
#  'Denmark': {'country_dummy': 0, 'pagerank_centrality': 0.00852100593569247},
#  'Djibouti': {'country_dummy': 0, 'pagerank_centrality': 0.000713236225186661},
#  'Dominica': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007138608233524168},
#  'Dominican Republic': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007904436472839251},
#  'Ecuador': {'country_dummy': 0, 'pagerank_centrality': 0.0007932425610550501},
#  'Egypt': {'country_dummy': 0, 'pagerank_centrality': 0.0009129131220536289},
#  'El Salvador': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007413181301072967},
#  'Equatorial Guinea': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007879732142856342},
#  'Estonia': {'country_dummy': 0, 'pagerank_centrality': 0.0009517757724369551},
#  'Ethiopia': {'country_dummy': 0, 'pagerank_centrality': 0.00072409496472906},
#  'Fiji': {'country_dummy': 0, 'pagerank_centrality': 0.0007115696593249153},
#  'Finland': {'country_dummy': 0, 'pagerank_centrality': 0.005686262673997592},
#  'France': {'country_dummy': 1, 'pagerank_centrality': 0.054286624851624714},
#  'French Territories: French Polynesia': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007166899602044727},
#  'French Territories: New Caledonia': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007233553929398177},
#  'Gabon': {'country_dummy': 0, 'pagerank_centrality': 0.0007338485916898253},
#  'Gambia, The': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007093401907813466},
#  'Georgia': {'country_dummy': 0, 'pagerank_centrality': 0.0007339897925669086},
#  'Germany': {'country_dummy': 1, 'pagerank_centrality': 0.05230349079800139},
#  'Ghana': {'country_dummy': 0, 'pagerank_centrality': 0.0007610267215501837},
#  'Gibraltar': {'country_dummy': 0,
#   'pagerank_centrality': 0.002458768945769243},
#  'Greece': {'country_dummy': 0, 'pagerank_centrality': 0.0023693173086174937},
#  'Greenland': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007104979405001457},
#  'Grenada': {'country_dummy': 0, 'pagerank_centrality': 0.0007086214752135048},
#  'Guatemala': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008004717209010079},
#  'Guernsey': {'country_dummy': 0, 'pagerank_centrality': 0.003728252446185387},
#  'Guinea': {'country_dummy': 0, 'pagerank_centrality': 0.0007113795821271255},
#  'Guinea-Bissau': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007084175608428303},
#  'Guyana': {'country_dummy': 0, 'pagerank_centrality': 0.000711306050510861},
#  'Haiti': {'country_dummy': 0, 'pagerank_centrality': 0.0007215902160453533},
#  'Honduras': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008016260126562156},
#  'Hungary': {'country_dummy': 0, 'pagerank_centrality': 0.0028682269911977105},
#  'Iceland': {'country_dummy': 0, 'pagerank_centrality': 0.0009514456356581602},
#  'India': {'country_dummy': 0, 'pagerank_centrality': 0.003245644387667184},
#  'Indonesia': {'country_dummy': 0,
#   'pagerank_centrality': 0.000866455186014811},
#  'Iran, Islamic Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0009694316163695432},
#  'Iraq': {'country_dummy': 0, 'pagerank_centrality': 0.0009394298974227519},
#  'Ireland': {'country_dummy': 1, 'pagerank_centrality': 0.01816020753786509},
#  'Isle of Man': {'country_dummy': 0,
#   'pagerank_centrality': 0.0015402524961733088},
#  'Israel': {'country_dummy': 0, 'pagerank_centrality': 0.002021430759104751},
#  'Italy': {'country_dummy': 1, 'pagerank_centrality': 0.021487221366825845},
#  'Jamaica': {'country_dummy': 0, 'pagerank_centrality': 0.0007349902060042289},
#  'Japan': {'country_dummy': 1, 'pagerank_centrality': 0.03647889322455096},
#  'Jersey': {'country_dummy': 0, 'pagerank_centrality': 0.006051482265419243},
#  'Jordan': {'country_dummy': 0, 'pagerank_centrality': 0.0012921015586857842},
#  'Kazakhstan': {'country_dummy': 0,
#   'pagerank_centrality': 0.0016230122231324987},
#  'Kenya': {'country_dummy': 0, 'pagerank_centrality': 0.0009099068254227368},
#  "Korea, Democratic People's Rep. of": {'country_dummy': 0,
#   'pagerank_centrality': 0.0007445698875230563},
#  'Korea, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.008280126156578147},
#  'Kosovo, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007313519670630019},
#  'Kuwait': {'country_dummy': 0, 'pagerank_centrality': 0.003377961682974147},
#  'Kyrgyz Republic': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007156657638711692},
#  "Lao People's Democratic Republic": {'country_dummy': 0,
#   'pagerank_centrality': 0.0007150574301950785},
#  'Latvia': {'country_dummy': 0, 'pagerank_centrality': 0.0009067285489168315},
#  'Lebanon': {'country_dummy': 0, 'pagerank_centrality': 0.0012653587357487294},
#  'Lesotho': {'country_dummy': 0, 'pagerank_centrality': 0.0007152182817749185},
#  'Liberia': {'country_dummy': 0, 'pagerank_centrality': 0.000823799743033409},
#  'Libya': {'country_dummy': 0, 'pagerank_centrality': 0.0013678157398696903},
#  'Liechtenstein': {'country_dummy': 0,
#   'pagerank_centrality': 0.001070418904800766},
#  'Lithuania': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008364949157537765},
#  'Luxembourg': {'country_dummy': 1,
#   'pagerank_centrality': 0.07323247442886983},
#  'Macedonia, FYR': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007494036137727541},
#  'Madagascar': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007214034721148671},
#  'Malawi': {'country_dummy': 0, 'pagerank_centrality': 0.0007138398767263205},
#  'Malaysia': {'country_dummy': 0, 'pagerank_centrality': 0.002010969151512949},
#  'Maldives': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007096745184410167},
#  'Mali': {'country_dummy': 0, 'pagerank_centrality': 0.0007431613978758838},
#  'Malta': {'country_dummy': 0, 'pagerank_centrality': 0.0013697452192281251},
#  'Marshall Islands, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008223222824269869},
#  'Mauritania': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007364921933040045},
#  'Mauritius': {'country_dummy': 0,
#   'pagerank_centrality': 0.0054887692661616675},
#  'Mexico': {'country_dummy': 0, 'pagerank_centrality': 0.0036991995820365047},
#  'Moldova': {'country_dummy': 0, 'pagerank_centrality': 0.0007199479254246013},
#  'Monaco': {'country_dummy': 0, 'pagerank_centrality': 0.0007273579231249022},
#  'Mongolia': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007117566433044471},
#  'Montenegro': {'country_dummy': 0,
#   'pagerank_centrality': 0.000921531723841436},
#  'Morocco': {'country_dummy': 0, 'pagerank_centrality': 0.0008394175723066085},
#  'Mozambique': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007372762419868665},
#  'Myanmar': {'country_dummy': 0, 'pagerank_centrality': 0.0007111858447685687},
#  'Namibia': {'country_dummy': 0, 'pagerank_centrality': 0.0007247120185686977},
#  'Nepal': {'country_dummy': 0, 'pagerank_centrality': 0.0007342469482074554},
#  'Netherlands': {'country_dummy': 1,
#   'pagerank_centrality': 0.06273404324073985},
#  'New Zealand': {'country_dummy': 0,
#   'pagerank_centrality': 0.001233334218575879},
#  'Nicaragua': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007458542018453226},
#  'Niger': {'country_dummy': 0, 'pagerank_centrality': 0.0007162511993121897},
#  'Nigeria': {'country_dummy': 0, 'pagerank_centrality': 0.0009695027505557156},
#  'Norway': {'country_dummy': 0, 'pagerank_centrality': 0.0115813485249739},
#  'Oman': {'country_dummy': 0, 'pagerank_centrality': 0.0010566719753056536},
#  'Pakistan': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008809129968192588},
#  'Panama': {'country_dummy': 0, 'pagerank_centrality': 0.00236406266385274},
#  'Papua New Guinea': {'country_dummy': 0,
#   'pagerank_centrality': 0.0009678668344691388},
#  'Paraguay': {'country_dummy': 0, 'pagerank_centrality': 0.00073567798613342},
#  'Peru': {'country_dummy': 0, 'pagerank_centrality': 0.0011700275254043096},
#  'Philippines': {'country_dummy': 0,
#   'pagerank_centrality': 0.0010027383254174519},
#  'Poland': {'country_dummy': 0, 'pagerank_centrality': 0.0018468288969334294},
#  'Portugal': {'country_dummy': 0,
#   'pagerank_centrality': 0.0033111954473261577},
#  'Puerto Rico': {'country_dummy': 0,
#   'pagerank_centrality': 0.000710805414192633},
#  'Qatar': {'country_dummy': 0, 'pagerank_centrality': 0.0018186286490159936},
#  'Romania': {'country_dummy': 0, 'pagerank_centrality': 0.0008762632803019137},
#  'Russian Federation': {'country_dummy': 0,
#   'pagerank_centrality': 0.006469479524156415},
#  'Rwanda': {'country_dummy': 0, 'pagerank_centrality': 0.0007105634539124484},
#  'Samoa': {'country_dummy': 0, 'pagerank_centrality': 0.0009656631054082423},
#  'San Marino': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007194226944268218},
#  'Sao Tome and Principe': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007086061826788296},
#  'Saudi Arabia': {'country_dummy': 0,
#   'pagerank_centrality': 0.004762948396668463},
#  'Senegal': {'country_dummy': 0, 'pagerank_centrality': 0.000892972118157663},
#  'Serbia, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0009718910606096892},
#  'Seychelles': {'country_dummy': 0,
#   'pagerank_centrality': 0.000857716841889753},
#  'Sierra Leone': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007097399003606591},
#  'Singapore': {'country_dummy': 0,
#   'pagerank_centrality': 0.011703794959890974},
#  'Sint Maarten': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007075471698113208},
#  'Slovak Republic': {'country_dummy': 0,
#   'pagerank_centrality': 0.0010115262929781814},
#  'Slovenia': {'country_dummy': 0,
#   'pagerank_centrality': 0.0012518491792902645},
#  'Solomon Islands': {'country_dummy': 0,
#   'pagerank_centrality': 0.00071004572078362},
#  'South Africa': {'country_dummy': 0,
#   'pagerank_centrality': 0.005547073682159238},
#  'Spain': {'country_dummy': 1, 'pagerank_centrality': 0.012949859676965604},
#  'Sri Lanka': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008800719744601689},
#  'St. Kitts and Nevis': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007291210866380297},
#  'St. Lucia': {'country_dummy': 0,
#   'pagerank_centrality': 0.000716463432537884},
#  'St. Vincent and the Grenadines': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007420576040364896},
#  'Sudan': {'country_dummy': 0, 'pagerank_centrality': 0.0007142367157863609},
#  'Suriname': {'country_dummy': 0, 'pagerank_centrality': 0.000715098336387914},
#  'Swaziland': {'country_dummy': 1,
#   'pagerank_centrality': 0.0007284753984131813},
#  'Sweden': {'country_dummy': 0, 'pagerank_centrality': 0.012677818283302358},
#  'Switzerland': {'country_dummy': 0,
#   'pagerank_centrality': 0.027246213296653665},
#  'Syrian Arab Republic': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007278209064873243},
#  'Taiwan Province of China': {'country_dummy': 0,
#   'pagerank_centrality': 0.006984394454943458},
#  'Tajikistan': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007092628253119679},
#  'Tanzania': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007494898328151509},
#  'Thailand': {'country_dummy': 0,
#   'pagerank_centrality': 0.0028590408852849263},
#  'Timor-Leste, Dem. Rep. of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007129971762345073},
#  'Togo': {'country_dummy': 0, 'pagerank_centrality': 0.0007160710888951279},
#  'Tonga': {'country_dummy': 0, 'pagerank_centrality': 0.0007079727868734954},
#  'Trinidad and Tobago': {'country_dummy': 0,
#   'pagerank_centrality': 0.0008409667533388627},
#  'Tunisia': {'country_dummy': 0, 'pagerank_centrality': 0.0007667008522140583},
#  'Turkey': {'country_dummy': 0, 'pagerank_centrality': 0.0036955539290673784},
#  'Turkmenistan': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007195522180484718},
#  'Turks and Caicos Islands': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007219735623109447},
#  'US Pacific Islands': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007081712746406155},
#  'US Virgin Islands': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007708750220109622},
#  'Uganda': {'country_dummy': 0, 'pagerank_centrality': 0.0007435313098460023},
#  'Ukraine': {'country_dummy': 0, 'pagerank_centrality': 0.0008426805264922607},
#  'United Arab Emirates': {'country_dummy': 0,
#   'pagerank_centrality': 0.004753740305085032},
#  'United Kingdom': {'country_dummy': 1,
#   'pagerank_centrality': 0.08346464851247583},
#  'United States': {'country_dummy': 1,
#   'pagerank_centrality': 0.14048378291662422},
#  'Uruguay': {'country_dummy': 0, 'pagerank_centrality': 0.0009345044755465823},
#  'Uzbekistan': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007470786415771798},
#  'Vanuatu': {'country_dummy': 0, 'pagerank_centrality': 0.0007135180806141557},
#  'Vatican': {'country_dummy': 0, 'pagerank_centrality': 0.0007139834790108878},
#  'Venezuela, Republica Bolivariana de': {'country_dummy': 0,
#   'pagerank_centrality': 0.001286666903459725},
#  'Vietnam': {'country_dummy': 0, 'pagerank_centrality': 0.0008145932575109948},
#  'Virgin Islands, British': {'country_dummy': 0,
#   'pagerank_centrality': 0.008781080036364908},
#  'West Bank and Gaza': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007611675282244095},
#  'Yemen, Republic of': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007235166590765404},
#  'Zambia': {'country_dummy': 0, 'pagerank_centrality': 0.0007286144949001677},
#  'Zimbabwe': {'country_dummy': 0,
#   'pagerank_centrality': 0.0007344458193846166}}

# %%
# ## export all files to gephi
# files = [(2009,'total_weight'),(2009,'loans_dep_weight'),(2009,'CDIS_weight'),(2009,'CPIS_weight'),
#          (2015,'total_weight'),(2015,'loans_dep_weight'),(2015,'CDIS_weight'),(2015,'CPIS_weight')]
# for x in files:
#     year,var = x 
#     G = export_gephi(df,year,var)
